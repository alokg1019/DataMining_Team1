# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_csv("/content/filtered_data.csv") ;
data
# Out:
#         Unnamed: 0  Invoice StockCode  ... Price  Customer ID         Country
# 0                0   489434     85048  ...  6.95      13085.0  United Kingdom
# 1                1   489434    79323P  ...  6.75      13085.0  United Kingdom
# 2                2   489434    79323W  ...  6.75      13085.0  United Kingdom
# 3                3   489434     22041  ...  2.10      13085.0  United Kingdom
# 4                4   489434     21232  ...  1.25      13085.0  United Kingdom
# ...            ...      ...       ...  ...   ...          ...             ...
# 400911      525456   538171     22271  ...  2.95      17530.0  United Kingdom
# 400912      525457   538171     22750  ...  3.75      17530.0  United Kingdom
# 400913      525458   538171     22751  ...  3.75      17530.0  United Kingdom
# 400914      525459   538171     20970  ...  3.75      17530.0  United Kingdom
# 400915      525460   538171     21931  ...  1.95      17530.0  United Kingdom
#
# [400916 rows x 9 columns]

# %%
print(data['Country'].unique())
# Stripping extra spaces in the descriptioni 
data['Description']= data['Description'].str.strip();
# Out:
# ['United Kingdom' 'France' 'USA' 'Belgium' 'Australia' 'EIRE' 'Germany'
#  'Portugal' 'Denmark' 'Netherlands' 'Poland' 'Channel Islands' 'Spain'
#  'Cyprus' 'Greece' 'Norway' 'Austria' 'Sweden' 'United Arab Emirates'
#  'Finland' 'Italy' 'Switzerland' 'Japan' 'Unspecified' 'Nigeria' 'Malta'
#  'RSA' 'Singapore' 'Bahrain' 'Thailand' 'Israel' 'Lithuania' 'West Indies'
#  'Korea' 'Brazil' 'Canada' 'Iceland']

# %%
basket_UK =(data
          .groupby(['Customer ID', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0))

# %%
basket_UK
# Out:
# Description  Customer ID  ...  ZINC WILLIE WINKIE  CANDLE STICK
# 0                12346.0  ...                               0.0
# 1                12347.0  ...                               0.0
# 2                12348.0  ...                               0.0
# 3                12349.0  ...                               0.0
# 4                12351.0  ...                               0.0
# ...                  ...  ...                               ...
# 4307             18283.0  ...                               0.0
# 4308             18284.0  ...                               0.0
# 4309             18285.0  ...                               0.0
# 4310             18286.0  ...                               0.0
# 4311             18287.0  ...                               0.0
#
# [4312 rows x 4407 columns]

# %%
basket_UK
custumers=basket_UK['Customer ID']
items=basket_UK.columns

# %%
items=items.drop('Customer ID')

# %%
custumers
# Out:
# RangeIndex(start=0, stop=4312, step=1)

# %%
items
# Out:
# Index(['10 COLOUR SPACEBOY PEN', '11 PC CERAMIC TEA SET POLKADOT',
#        '12 ASS ZINC CHRISTMAS DECORATIONS', '12 COLOURED PARTY BALLOONS',
#        '12 DAISY PEGS IN WOOD BOX', '12 EGG HOUSE PAINTED WOOD',
#        '12 IVORY ROSE PEG PLACE SETTINGS', '12 MESSAGE CARDS WITH ENVELOPES',
#        '12 MINI TOADSTOOL PEGS', '12 PENCIL SMALL TUBE WOODLAND',
#        ...
#        'ZINC HEART LATTICE CHARGER LARGE', 'ZINC HEART LATTICE CHARGER SMALL',
#        'ZINC HEART LATTICE DOUBLE PLANTER', 'ZINC HEART LATTICE PLANTER BOWL',
#        'ZINC HEART LATTICE T-LIGHT HOLDER', 'ZINC HEART LATTICE TRAY OVAL',
#        'ZINC METAL HEART DECORATION', 'ZINC POLICE BOX LANTERN',
#        'ZINC TOP  2 DOOR WOODEN SHELF', 'ZINC WILLIE WINKIE  CANDLE STICK'],
#       dtype='object', name='Description', length=4406)

# %%
new_data=basket_UK.set_index('Customer ID')
basket=basket_UK.set_index('Customer ID')
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# Customer ID                          ...
# 12346.0                         0.0  ...                               0.0
# 12347.0                        24.0  ...                               0.0
# 12348.0                         0.0  ...                               0.0
# 12349.0                         0.0  ...                               0.0
# 12351.0                         0.0  ...                               0.0
# ...                             ...  ...                               ...
# 18283.0                         0.0  ...                               0.0
# 18284.0                        24.0  ...                               0.0
# 18285.0                         0.0  ...                               0.0
# 18286.0                        24.0  ...                               0.0
# 18287.0                         0.0  ...                               0.0
#
# [4312 rows x 4406 columns]

# %%
final_movie = basket.fillna(basket.mean(axis=0))
final_movie.index
# Out:
# Float64Index([12346.0, 12347.0, 12348.0, 12349.0, 12351.0, 12352.0, 12353.0,
#               12355.0, 12356.0, 12357.0,
#               ...
#               18277.0, 18278.0, 18279.0, 18280.0, 18281.0, 18283.0, 18284.0,
#               18285.0, 18286.0, 18287.0],
#              dtype='float64', name='Customer ID', length=4312)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-264a0d3284d4> in <module>()
# ----> 1 final_movie=final_movie.set_index('Customer ID')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Customer ID'] are in the columns"

# %%
cosine = cosine_similarity(final_movie)
np.fill_diagonal(cosine, 0 )
similarity_with_movie =pd.DataFrame(cosine,index=final_movie.index)
similarity_with_movie.columns=custumers
similarity_with_movie.head()
# Out:
# Customer ID   12346.0   12347.0   12348.0  ...  18285.0   18286.0   18287.0
# Customer ID                                ...
# 12346.0      0.000000  0.000000  0.000000  ...      0.0  0.001406  0.000000
# 12347.0      0.000000  0.000000  0.110042  ...      0.0  0.068004  0.007098
# 12348.0      0.000000  0.110042  0.000000  ...      0.0  0.000000  0.000000
# 12349.0      0.002661  0.009302  0.000154  ...      0.0  0.044175  0.047580
# 12351.0      0.000000  0.153883  0.000000  ...      0.0  0.022601  0.009068
#
# [5 rows x 4312 columns]

# %%
new_data.columns
# Out:
# Index(['10 COLOUR SPACEBOY PEN', '11 PC CERAMIC TEA SET POLKADOT',
#        '12 ASS ZINC CHRISTMAS DECORATIONS', '12 COLOURED PARTY BALLOONS',
#        '12 DAISY PEGS IN WOOD BOX', '12 EGG HOUSE PAINTED WOOD',
#        '12 IVORY ROSE PEG PLACE SETTINGS', '12 MESSAGE CARDS WITH ENVELOPES',
#        '12 MINI TOADSTOOL PEGS', '12 PENCIL SMALL TUBE WOODLAND',
#        ...
#        'ZINC HEART LATTICE CHARGER LARGE', 'ZINC HEART LATTICE CHARGER SMALL',
#        'ZINC HEART LATTICE DOUBLE PLANTER', 'ZINC HEART LATTICE PLANTER BOWL',
#        'ZINC HEART LATTICE T-LIGHT HOLDER', 'ZINC HEART LATTICE TRAY OVAL',
#        'ZINC METAL HEART DECORATION', 'ZINC POLICE BOX LANTERN',
#        'ZINC TOP  2 DOOR WOODEN SHELF', 'ZINC WILLIE WINKIE  CANDLE STICK'],
#       dtype='object', name='Description', length=4406)

# %%
new_data=new_data.T

# %%
new_data
# Out:
# Customer ID                        12346.0  12347.0  ...  18286.0  18287.0
# Description                                          ...
# 10 COLOUR SPACEBOY PEN                 0.0     24.0  ...     24.0      0.0
# 11 PC CERAMIC TEA SET POLKADOT         0.0      0.0  ...      0.0      0.0
# 12 ASS ZINC CHRISTMAS DECORATIONS      0.0      0.0  ...      0.0      0.0
# 12 COLOURED PARTY BALLOONS             0.0      0.0  ...      0.0      0.0
# 12 DAISY PEGS IN WOOD BOX              0.0      0.0  ...      0.0      0.0
# ...                                    ...      ...  ...      ...      ...
# ZINC HEART LATTICE TRAY OVAL           0.0      0.0  ...      0.0      0.0
# ZINC METAL HEART DECORATION            0.0      0.0  ...      0.0      0.0
# ZINC POLICE BOX LANTERN                0.0      0.0  ...      0.0      0.0
# ZINC TOP  2 DOOR WOODEN SHELF          0.0      0.0  ...      0.0      0.0
# ZINC WILLIE WINKIE  CANDLE STICK       0.0      0.0  ...      0.0      0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
item_sim_df = pd.DataFrame(cosine_similarity(new_data, new_data), index=new_data.index, columns=new_data.index)
item_sim_df.head()
# Out:
# Description                        10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# Description                                                ...
# 10 COLOUR SPACEBOY PEN                           1.000000  ...                          0.086600
# 11 PC CERAMIC TEA SET POLKADOT                   0.034789  ...                          0.000000
# 12 ASS ZINC CHRISTMAS DECORATIONS                0.000141  ...                          0.040112
# 12 COLOURED PARTY BALLOONS                       0.042964  ...                          0.014034
# 12 DAISY PEGS IN WOOD BOX                        0.051271  ...                          0.073654
#
# [5 rows x 4406 columns]

# %%
final_movie = final.fillna(final.mean(axis=0))
# Out:
# Description                        10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# Description                                                ...
# 10 COLOUR SPACEBOY PEN                              False  ...                             False
# 11 PC CERAMIC TEA SET POLKADOT                      False  ...                             False
# 12 ASS ZINC CHRISTMAS DECORATIONS                   False  ...                             False
# 12 COLOURED PARTY BALLOONS                          False  ...                             False
# 12 DAISY PEGS IN WOOD BOX                           False  ...                             False
# ...                                                   ...  ...                               ...
# ZINC HEART LATTICE TRAY OVAL                        False  ...                             False
# ZINC METAL HEART DECORATION                         False  ...                             False
# ...

# %%
def get_similar_anime(anime_name):
    if anime_name not in new_data.index:
        return None, None
    else:
        sim_animes = item_sim_df.sort_values(by=anime_name, ascending=False).index[1:]
        sim_score = item_sim_df.sort_values(by=anime_name, ascending=False).loc[:, anime_name].tolist()[1:]
        return sim_animes, sim_score

# %%
animes, score = get_similar_anime('12 ASS ZINC CHRISTMAS DECORATIONS')
for x,y in zip(animes[:10], score[:10]):
    print("{} with similarity of {}".format(x, y))
# Out:
# CUT GLASS T-LIGHT HOLDER OCTAGON with similarity of 0.39671036373016016
# TRIANGULAR RIDGED GLASS POSY HOLDER with similarity of 0.21030027720879824
# BLACK RECORD COVER FRAME with similarity of 0.20500499248478785
# CERAMIC STRAWBERRY TRINKET TRAY with similarity of 0.2036915471144584
# FAIRY CAKE CERAMIC BUTTER DISH with similarity of 0.1985346818355613
# ETCHED GLASS STAR TREE DECORATION with similarity of 0.19002751663206288
# RED REINDEER STRING OF 20 LIGHTS with similarity of 0.168629933697079
# MOROCCAN BEATEN METAL DISH with similarity of 0.16676735251841912
# ANGEL DECORATION STARS ON DRESS with similarity of 0.15355641707584874
# SMALL HANGING IVORY/RED WOOD BIRD with similarity of 0.15219783038968182

# %%
items=['12 ASS ZINC CHRISTMAS DECORATIONS','12 COLOURED PARTY BALLOONS']

def get_rc(arr):
  res = {}
  for i in arr:
    animes, score = get_similar_anime(i)
    for x,y in zip(animes[:10], score[:10]):
      if x in res:
        if res[x] > y:
          continue
        else:
          res[x] = y
      else:
        res[x] = y
          
  return res
    
resp = get_rc(items)
res = sorted(resp.items(), reverse=True, key=lambda x: x[1])
print(res)
# Out:
# [('SAVE THE PLANET COTTON TOTE BAG', 0.9104783035976797), ('MAGNETS PACK OF 4 VINTAGE COLLAGE', 0.8900696841088993), ('MAGIC DRAWING SLATE DINOSAUR', 0.8812436242995388), ('EASTER CRAFT IVY WREATH WITH CHICK', 0.8572010949657745), ('WOODLAND PARTY BAG + STICKER SET', 0.8337442805462084), ('MINI HIGHLIGHTER PENS', 0.8244774418426081), ('MAGIC DRAWING SLATE SPACEBOY', 0.8129907558665912), ('MAGIC DRAWING SLATE DOLLY GIRL', 0.8127932554909505), ('MAGNETS PACK OF 4 CHILDHOOD MEMORY', 0.770718701402017), ('LUNCH BAG SUKI  DESIGN', 0.7628788346557364), ('CUT GLASS T-LIGHT HOLDER OCTAGON', 0.39671036373016016), ('TRIANGULAR RIDGED GLASS POSY HOLDER', 0.21030027720879824), ('BLACK RECORD COVER FRAME', 0.20500499248478785), ('CERAMIC STRAWBERRY TRINKET TRAY', 0.2036915471144584), ('FAIRY CAKE CERAMIC BUTTER DISH', 0.1985346818355613), ('ETCHED GLASS STAR TREE DECORATION', 0.19002751663206288), ('RED REINDEER STRING OF 20 LIGHTS', 0.168629933697079), ('MOROCCAN BEATEN METAL DISH', 0.1667673525
# ...
