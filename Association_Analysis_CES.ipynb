# %% [markdown]
# ## Association analysis for CES Hybrid dataset

# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# loading preprocessed and cleaned CES hybrid dataset into a pandas dataframe
PATH = '/content/preprocessed_ces_hybrid.csv'

data = pd.read_csv(PATH)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57860 entries, 0 to 57859
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           57860 non-null  int64
#  1   city         57860 non-null  object
#  2   income       57860 non-null  object
#  3   members      57860 non-null  object
#  4   description  57860 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ MB

# %%
data.shape
# Out:
# (57860, 5)

# %%
data.head()
# Out:
#       id   city    income members     description
# 0  10001  Belem  25_to_43       4      beef_liver
# 1  10001  Belem  25_to_43       4     beer_snacks
# 2  10001  Belem  25_to_43       4        beetroot
# 3  10001  Belem  25_to_43       4    black_grapes
# 4  10001  Belem  25_to_43       4  borlotti_beans

# %%
# The columns of our dataset?
cols = data.columns
print('Columns in our data: ', list(cols))
# Out:
# Columns in our data:  ['id', 'city', 'income', 'members', 'description']

# %%
data['quantity'] = 1

# %%
data.head()
# Out:
#       id   city    income members     description  quantity
# 0  10001  Belem  25_to_43       4      beef_liver         1
# 1  10001  Belem  25_to_43       4     beer_snacks         1
# 2  10001  Belem  25_to_43       4        beetroot         1
# 3  10001  Belem  25_to_43       4    black_grapes         1
# 4  10001  Belem  25_to_43       4  borlotti_beans         1

# %%
data.head()
# Out:
#       id   city    income members     description  quantity
# 0  10001  Belem  25_to_43       4      beef_liver         1
# 1  10001  Belem  25_to_43       4     beer_snacks         1
# 2  10001  Belem  25_to_43       4        beetroot         1
# 3  10001  Belem  25_to_43       4    black_grapes         1
# 4  10001  Belem  25_to_43       4  borlotti_beans         1

# %%
#Unique items in our dataset
print('Unique Items: ', data['description'].nunique())
# Out:
# Unique Items:  735

# %%
# Different cities that the transactions are from: 
countries = list(data['city'].unique())
countries
# Out:
# ['Belem',
#  'Belo_Horizonte',
#  'Curitiba',
#  'Florianopolis',
#  'Fortaleza',
#  'Goiania',
#  'Porto_Alegre',
#  'Recife']

# %%
#Transactions for each city
d = data.groupby('city')
d.describe()
# Out:
#                     id                                    ... quantity
#                  count          mean        std      min  ...      25%  50%  75%  max
# city                                                      ...
# Belem           6140.0  10060.392671  40.479884  10001.0  ...      1.0  1.0  1.0  1.0
# Belo_Horizonte  7104.0  20107.816441  60.966973  20001.0  ...      1.0  1.0  1.0  1.0
# Curitiba        7459.0  40105.405684  60.086019  40001.0  ...      1.0  1.0  1.0  1.0
# Florianopolis   8361.0  50102.356895  53.652008  50001.0  ...      1.0  1.0  1.0  1.0
# Fortaleza       7194.0  60098.990409  66.348702  60001.0  ...      1.0  1.0  1.0  1.0
# Goiania         8138.0  70096.658270  50.398211  70001.0  ...      1.0  1.0  1.0  1.0
# Porto_Alegre    6847.0  80103.484592  60.060711  80001.0  ...      1.0  1.0  1.0  1.0
# Recife          6617.0  90103.928820  57.320776  90001.0  ...      1.0  1.0  1.0  1.0
#
# [8 rows x 16 columns]

# %%
#Now splitting data according to the city of transaction 

# Transactions done in Belem 
basket_Belem = (data[data['city'] == 'Belem'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Belem.head()
# Out:
# description  acai_berry  ...  yogurt_with_honey
# id                       ...
# 10001               0.0  ...                0.0
# 10002               0.0  ...                0.0
# 10003               0.0  ...                0.0
# 10004               0.0  ...                0.0
# 10005               0.0  ...                0.0
#
# [5 rows x 585 columns]

# %%
basket_Belem.shape
# Out:
# (139, 585)

# %%
# Transactions done in Belo_Horizonte 
basket_Belo_Horizonte = (data[data['city'] == 'Belo_Horizonte'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Belo_Horizonte.head()
# Out:
# description  acai_berry  ...  yogurt_with_honey
# id                       ...
# 20001               0.0  ...                0.0
# 20002               0.0  ...                0.0
# 20003               0.0  ...                0.0
# 20004               0.0  ...                0.0
# 20005               0.0  ...                0.0
#
# [5 rows x 536 columns]

# %%
# Transactions done in Curitiba 
basket_Curitiba = (data[data['city'] == 'Curitiba'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Curitiba.head()
# Out:
# description  acai_berry_pulp  ...  yogurt_with_honey
# id                            ...
# 40001                    0.0  ...                0.0
# 40002                    0.0  ...                0.0
# 40003                    0.0  ...                0.0
# 40004                    0.0  ...                0.0
# 40005                    0.0  ...                0.0
#
# [5 rows x 542 columns]

# %%
# Transactions done in Florianopolis 
basket_Florianopolis = (data[data['city'] == 'Florianopolis'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Florianopolis.head()
# Out:
# description  acai_berry_pulp  ...  yogurt_with_honey
# id                            ...
# 50001                    0.0  ...                0.0
# 50002                    0.0  ...                0.0
# 50004                    0.0  ...                0.0
# 50005                    0.0  ...                0.0
# 50006                    0.0  ...                0.0
#
# [5 rows x 556 columns]

# %%
# Transactions done in Fortaleza 
basket_Fortaleza = (data[data['city'] == 'Fortaleza'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Fortaleza.head()
# Out:
# description  ajinomoto_sauce  alphabet_pasta  ...  yeast  yogurt_with_fruit_pieces
# id                                            ...
# 60001                    0.0             0.0  ...    0.0                       0.0
# 60002                    0.0             0.0  ...    0.0                       1.0
# 60003                    0.0             0.0  ...    0.0                       0.0
# 60004                    0.0             0.0  ...    0.0                       0.0
# 60005                    0.0             0.0  ...    0.0                       0.0
#
# [5 rows x 480 columns]

# %%
# Transactions done in Goiania 
basket_Goiania = (data[data['city'] == 'Goiania'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Goiania.head()
# Out:
# description  acai_berry_pulp  ...  yogurt_with_fruit_pieces
# id                            ...
# 70001                    0.0  ...                       0.0
# 70002                    0.0  ...                       1.0
# 70003                    0.0  ...                       0.0
# 70004                    0.0  ...                       0.0
# 70005                    0.0  ...                       1.0
#
# [5 rows x 514 columns]

# %%
# Transactions done in Porto_Alegre 
basket_Porto_Alegre = (data[data['city'] == 'Porto_Alegre'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Porto_Alegre.head()
# Out:
# description  acai_berry_pulp  ...  yogurt_with_honey
# id                            ...
# 80001                    0.0  ...                0.0
# 80002                    0.0  ...                0.0
# 80003                    0.0  ...                0.0
# 80004                    0.0  ...                0.0
# 80005                    0.0  ...                0.0
#
# [5 rows x 506 columns]

# %%
# Transactions done in Recife 
basket_Recife = (data[data['city'] == 'Recife'].groupby(['id', 'description'])['quantity']
                .sum().unstack().reset_index()
                .fillna(0)
                .set_index('id'))
  
basket_Recife.head()
# Out:
# description  acai_berry  ...  yogurt_with_honey
# id                       ...
# 90001               0.0  ...                0.0
# 90002               0.0  ...                0.0
# 90003               0.0  ...                0.0
# 90004               0.0  ...                1.0
# 90005               0.0  ...                0.0
#
# [5 rows x 468 columns]

# %%
#Defining hot encoding function to make data suitable for apriori

def hot_encode(x): 
    if( x == 1):
        return 1
    if( x < 1):
        return 0

# %%
#Encoding the datasets

basket_encoded = basket_Belem.applymap(hot_encode)
basket_Belem = basket_encoded 

basket_encoded = basket_Belo_Horizonte.applymap(hot_encode)
basket_Belo_Horizonte = basket_encoded 

basket_encoded = basket_Curitiba.applymap(hot_encode)
basket_Curitiba = basket_encoded 

basket_encoded = basket_Florianopolis.applymap(hot_encode)
basket_Florianopolis = basket_encoded 
 
basket_encoded = basket_Fortaleza.applymap(hot_encode)
basket_Fortaleza = basket_encoded 

basket_encoded = basket_Goiania.applymap(hot_encode)
basket_Goiania = basket_encoded 

basket_encoded = basket_Porto_Alegre.applymap(hot_encode)
basket_Porto_Alegre = basket_encoded 

basket_encoded = basket_Recife.applymap(hot_encode)
basket_Recife = basket_encoded

# %%
#Building a model for each country 
#Using apriori analysis with min_support = 0.07

#For city Belem  
frq_items = apriori(basket_Belem, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7) 

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                               antecedents  ... conviction
# 525470           (potato, garlic, ketchup, whipped_cream)  ...        inf
# 693222  (garlic, chocolate_powder, condensed_milk, sun...  ...        inf
# 144982  (ketchup, french_toast, condensed_milk, oat_fl...  ...        inf
# 144983     (ketchup, beef_rump, french_toast, oat_flakes)  ...        inf
# 693201  (frozen_chicken, garlic, chocolate_powder, con...  ...        inf
#
# [5 rows x 9 columns]

# %%
# Out:
#                                                antecedents  ... conviction
# 1071400  (frozen_chicken, cream_cracker_biscuits, granu...  ...        inf
# 447019                        (annatto, mayonnaise, cumin)  ...        inf
# 1126846  (ketchup, whipped_cream, frozen_chicken, granu...  ...        inf
# 61047                (beef_rump, whipped_cream, olive_oil)  ...        inf
# 736387   (frozen_chicken, whipped_cream, granulated_sug...  ...        inf
#
# [5 rows x 9 columns]

# %%
#Building a model for each country 
#Using apriori analysis with min_support = 0.07

#For city Belo Horizonte  
frq_items = apriori(basket_Belo_Horizonte, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7)

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                               antecedents  ... conviction
# 52932   (canned_peas, garlic, chocolate_powder, granul...  ...        inf
# 75678   (soy_oil, mayonnaise, granulated_sugar, yogurt...  ...        inf
# 31705   (banana, pinto_beans, beetroot, granulated_sugar)  ...        inf
# 85139   (egg, granulated_sugar, garlic, butter, beetroot)  ...        inf
# 157065  (egg, french_bread, garlic, butter, chocolate_...  ...        inf
#
# [5 rows x 9 columns]

# %%
#Building a model for each country 
#Using apriori analysis with min_support = 0.07

#For city Curitiba 
frq_items = apriori(basket_Curitiba, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7)

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                               antecedents  ... conviction
# 55466   (chocolate_powder, cucumber, creamy_white_chee...  ...        inf
# 115455  (egg, sausage, wheat_flour_special, watermelon...  ...        inf
# 125788  (french_bread, cucumber, chocolate_powder, cau...  ...        inf
# 14943              (canned_peas, ketchup, canned_sardine)  ...        inf
# 14951            (canned_peas, pineapple, canned_sardine)  ...        inf
#
# [5 rows x 9 columns]

# %%
#Building a model for each city 
#Using apriori analysis with min_support = 0.07

#For city Florianopolis 
frq_items = apriori(basket_Florianopolis, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7)

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                                antecedents  ... conviction
# 3295290  (amazon_papaya, sausage, cabbage, french_bread...  ...        inf
# 2010752  (egg, garlic, chocolate_powder, beef_burger, l...  ...        inf
# 5152476  (frozen_pizza, sausage, niagara_grapes, waterm...  ...        inf
# 4163132  (egg, sausage, jam, watermelon, chocolate_powd...  ...        inf
# 459511            (jam, canned_peas, green_beans, soy_oil)  ...        inf
#
# [5 rows x 9 columns]

# %%
#Building a model for each city 
#Using apriori analysis with min_support = 0.07

#For city Florianopolis 
frq_items = apriori(basket_Fortaleza, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7) 

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                                antecedents  ... conviction
# 1178975  (annatto, pepper, flour, garlic, cream_cracker...  ...        inf
# 848099   (pepper, tomato, granulated_sugar, carrot, onion)  ...        inf
# 847768   (spread_margarine, granulated_sugar, cream_cra...  ...        inf
# 847792   (spread_margarine, granulated_sugar, cream_cra...  ...        inf
# 847808   (orange, granulated_sugar, cream_cracker_biscu...  ...        inf
#
# [5 rows x 9 columns]

# %%
#For city Goiania 
frq_items = apriori(basket_Goiania, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7)

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()

# %%
#For city Porto_Alegre 
frq_items = apriori(basket_Porto_Alegre, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7)

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                              antecedents  ... conviction
# 23180  (potato, tomato, chocolate_powder, vinegar, ma...  ...        inf
# 19705            (vinegar, watermelon, saveloy, soy_oil)  ...        inf
# 19683  (soy_oil, saveloy, wheat_flour_special, soda_b...  ...        inf
# 19671     (vinegar, saveloy, soda_bottle_large, soy_oil)  ...        inf
# 19655                   (potato, vinegar, tomato, sugar)  ...        inf
#
# [5 rows x 9 columns]

# %%
#For city Recife 
frq_items = apriori(basket_Recife, min_support = 0.07, use_colnames = True)
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='confidence' and mininum threshold = 0.7 (70% of confidence or above)
rules = association_rules(frq_items, metric ="confidence", min_threshold=0.7)

rules = rules.sort_values(by=['confidence'],ascending=False)
rules.head()
# Out:
#                                               antecedents  ... conviction
# 207297         (egg, coriander, flour, cucumber, vinegar)  ...        inf
# 142044  (banana, canned_sardine, french_bread, waterme...  ...        inf
# 95080   (guava_candy, cucumber, mayonnaise, canned_sar...  ...        inf
# 142034  (banana, canned_sardine, tomato, vinegar, cann...  ...        inf
# 142033  (banana, canned_sardine, tomato, french_bread,...  ...        inf
#
# [5 rows x 9 columns]
